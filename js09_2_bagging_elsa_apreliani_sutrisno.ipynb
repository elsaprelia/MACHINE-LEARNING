# %% [markdown]
# <a href="https://colab.research.google.com/github/elsaprelia/MACHINE-LEARNING/blob/main/js09_2_bagging_elsa_apreliani_sutrisno.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Bagging dengan RandomForest
#
# Pada kasus ini kita akan menggunakan salah satu metode bagging yaitu RandomForest untuk mengklasifikasikan jenis tumor. Dalam latihan ini Anda akan melakukan training dengan data [Wisconsin Breast Cancer Dataset](https://www.kaggle.com/uciml/breast-cancer-wisconsin-data) dari UCI machine learning repository. Latihan ini akan melakukan prediksi memprediksi apakah tumor ganas atau jinak.
#
# Kita akan membandingkan performa dari algoritma Decision Tree dan RandomForest pada kasus ini.

# %% [markdown]
# ### Import Library

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeClassifier # import DT
from sklearn.ensemble import RandomForestClassifier # import RandomForest
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ### Persiapan Data

# %%
# Load data
df = pd.read_csv('wbc.csv')

df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# Cek kolom null
df.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# Seleksi fitur

# Slice dataframe mulai dari kolom 'radius_mean' sampai 'fractal_dimension_worst'
X = df.iloc[:,3:-1]
y = df['diagnosis']
y = y.map({'M':1, 'B':0}) # Encode label

# Cek jumlah fitur dan instance
X.shape
# Out:
# (569, 29)

# %% [markdown]
# ### Split data training dan testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %% [markdown]
# ### Traning Decision Tree

# %%
# Secara default, DecisionTreeClassifier dari scikit-learn akan menggunakan nilai "Gini" untuk kriteria
# Terdapat beberapa "hyperparamater" yang dapat digunakan. Silahka baca dokumentasi
# Pada kasus ini kita akan menggunakan parameter default
dt = DecisionTreeClassifier()

# Sesuaikan dt ke set training
dt.fit(X_train, y_train)

# Memprediksi label set test
y_pred_dt = dt.predict(X_test)

#  menghitung set accuracy
acc_dt = accuracy_score(y_test, y_pred_dt)
print("Test set accuracy: {:.2f}".format(acc_dt))
print(f"Test set accuracy: {acc_dt}")
# Out:
# Test set accuracy: 0.96
# Test set accuracy: 0.956140350877193

# %% [markdown]
# ### Training RandomForest

# %%
# Pada kasus kali ini kita akan menggunakan seluruh parameter default dari RandomForest
# Untuk detail parameter (hyperparameter) silahkan cek dokumentasi

rf = RandomForestClassifier(n_estimators=10, random_state=1)

# Sesuaikan dt ke set training
rf.fit(X_train, y_train)

# Memprediksi label set test
y_pred_rf = rf.predict(X_test)

#  menghitung set accuracy
acc_rf = accuracy_score(y_test, y_pred_rf)
print("Test set accuracy: {:.2f}".format(acc_rf))
print(f"Test set accuracy: {acc_rf}")
# Out:
# Test set accuracy: 0.96
# Test set accuracy: 0.956140350877193

# %% [markdown]
# ### Tugas
#
# Pada folder data, terdapat dataset jamur yang kita gunakan pada materi Decision Tree. Berdasarkan dataset yang sama, bandingkan peforma antara algoritma DT dan RandomForest. Gunakan tunning hyperparameter untuk mendapatkan parameter dan akurasi yang terbaik.

# %% [markdown]
# **Decission Tree**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Pre-process

# %%
cancer = pd.read_csv('wbc.csv')
cancer.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# describe
cancer.describe()
# Out:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %%
# display basic info about data type
cancer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
# display number of samples on each class
cancer['diagnosis'].value_counts()
# Out:
# B    357
# M    212
# Name: diagnosis, dtype: int64

# %%
# check for null values
cancer.isnull().sum()
# Out:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# concave points_worst         0
# ...

# %%
# use LabelEncoder to convert it to ordinal
cancer = cancer.astype('category')
cancer.dtypes
# Out:
# id                         category
# diagnosis                  category
# radius_mean                category
# texture_mean               category
# perimeter_mean             category
# area_mean                  category
# smoothness_mean            category
# compactness_mean           category
# concavity_mean             category
# concave points_mean        category
# symmetry_mean              category
# fractal_dimension_mean     category
# radius_se                  category
# texture_se                 category
# perimeter_se               category
# area_se                    category
# smoothness_se              category
# compactness_se             category
# concavity_se               category
# concave points_se          category
# symmetry_se                category
# fractal_dimension_se       category
# radius_worst               category
# texture_worst              category
# perimeter_worst            category
# area_worst                 category
# ...

# %%
# Use LabelEncoder to make the columns into machine understandable format.
# Using LabelEncoder to convert catergory values to ordinal
from sklearn.preprocessing import LabelEncoder
labelencoder=LabelEncoder()
for column in cancer.columns:
    cancer[column] = labelencoder.fit_transform(cancer[column])

cancer.head()
# Out:
#     id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0   41          1          370             1             455        452
# 1   42          1          426           186             486        513
# 2  488          1          406           324             478        487
# 3  489          1           98           297             164         95
# 4  490          1          418            60             493        506
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0              444               531             521                  526
# 1              120               215             321                  396
# 2              403               459             478                  516
# 3              471               533             507                  493
# 4              332               414             480                  492
#
#    ...  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %% [markdown]
# Train Data (ambil acuan dari data radius dan texture)

# %%
X = cancer[['radius_mean', 'texture_mean','perimeter_mean']].values
y = cancer['diagnosis'].values
# y = y.map({'M':1, 'B':0})

# %%
# creating the training and testing data
from sklearn.model_selection import train_test_split

# y = mshr["class"].values

# x = mshr.drop(["class"], axis=1).values

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.2)

# %%
from sklearn.tree import DecisionTreeClassifier

# Instantiate DecisionTreeClassifier 'mshr' dengan kedalaman maksimum 6
cancer = DecisionTreeClassifier(max_depth=6, random_state=1)

# Sesuaikan mshr ke set training
cancer.fit(X_train, y_train)

# Pmemprediksi label set test
y_pred = cancer.predict(X_test)
print(y_pred[0:5])
# Out:
# [1 0 0 1 1]

# %% [markdown]
# Evaluasi Classification Tree

# %%
from sklearn.metrics import accuracy_score

# Memprediksi test set labels
y_pred = cancer.predict(X_test)

#  menghitung set accuracy
acc = accuracy_score(y_test, y_pred)
print("Test set accuracy: {:.2f}".format(acc))
# Out:
# Test set accuracy: 0.85

# %% [markdown]
# Kesimpulan :
# Setelah menggunakan 2 metode antara decision tree dan bagging dengan randomforest mendapatkan hasil akurasi yang berbeda. apabila menggunakan decision tree akan mendapatkan skor akurasi sebesar 0.85. Sedangkan menggunakan bagging dengan randomforest akan mendapatkan skor sebesar 0.96. Dari hasil skor tersebut bisa disimpulkan bahwa bagging dengan randomforest memiliki skor akurasi yang lebih tinggi dan lebih akurat daripada decision tree
